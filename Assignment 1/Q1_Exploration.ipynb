# %%
# !pip install --upgrade transformers
# !pip install --upgrade accelerate
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 8.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.33.0
#     Uninstalling accelerate-0.33.0:
#       Successfully uninstalled accelerate-0.33.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 6.6 MB/s eta 0:00:00
# ...

# %%
import torch
import warnings
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig

warnings.filterwarnings('ignore')

# %%
from huggingface_hub import login

login("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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Llama 8B

# %%
# loading the model from huggingface
model_id = "meta-llama/Meta-Llama-3-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
inputs = tokenizer("who was the first black scientist in Brazil", return_tensors="pt")
input_ids = inputs["input_ids"].to('cuda')

# %%
generation_config = GenerationConfig(
    temperature = 0.1,
    max_new_tokens = 150
)

# %%
with torch.no_grad():
    generation_output = model.generate(
        input_ids=input_ids,
        attention_mask=torch.ones_like(input_ids),
        generation_config=generation_config,
    )
output_text = tokenizer.decode(generation_output[0].cuda(), skip_special_tokens=True).strip()
print(output_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# who was the first black scientist in Brazil?
# The first black scientist in Brazil was José Bonifácio de Andrada e Silva, a geologist, chemist, and politician who was born in 1763 in São Paulo, Brazil. He was the first black person to graduate from the University of São Paulo and the first black person to hold a chair in a Brazilian university. Andrada e Silva was a prominent figure in the Brazilian scientific community and was known for his work on the geology and mineralogy of Brazil. He was

# %%
inputs = tokenizer("name a One eyed animal", return_tensors="pt")
input_ids = inputs["input_ids"].to('cuda')

# %%
with torch.no_grad():
    generation_output = model.generate(
        input_ids=input_ids,
        attention_mask=torch.ones_like(input_ids),
        generation_config=generation_config,
    )
output_text = tokenizer.decode(generation_output[0].cuda(), skip_special_tokens=True).strip()
print(output_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# name a One eyed animal
# One-eyed animals are quite fascinating, aren't they? Here are a few examples:
#
# 1. **Lizards**: Many species of lizards, such as the one-eyed gecko (Oedura monilis), have a tendency to lose one eye due to injury or disease.
# 2. **Fish**: Some fish, like the one-eyed catfish (Synodontis nigriventris), have a congenital condition that causes them to be born with only one eye.
# 3. **Snakes**: Some species of snakes, such as the one-eyed viper (Trimeresurus flavoviridis), have a condition called "ophthalmia," which causes them to lose one eye.
# 4. **Turtles**: Some turtles, like

# %%
inputs = tokenizer("what walks on water", return_tensors="pt")
input_ids = inputs["input_ids"].to('cuda')

# %%
with torch.no_grad():
    generation_output = model.generate(
        input_ids=input_ids,
        attention_mask=torch.ones_like(input_ids),
        generation_config=generation_config,
    )
output_text = tokenizer.decode(generation_output[0].cuda(), skip_special_tokens=True).strip()
print(output_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# what walks on water
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water? A duck! (get it?)
# What walks on water?

# %%
inputs = tokenizer("animal that is born with 3 legs but goes up to the hill with 4 legs", return_tensors="pt")
input_ids = inputs["input_ids"].to('cuda')

# %%
with torch.no_grad():
    generation_output = model.generate(
        input_ids=input_ids,
        attention_mask=torch.ones_like(input_ids),
        generation_config=generation_config,
    )
output_text = tokenizer.decode(generation_output[0].cuda(), skip_special_tokens=True).strip()
print(output_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# animal that is born with 3 legs but goes up to the hill with 4 legs
# The answer is a kangaroo. A kangaroo is born with three legs, but as it grows, the third leg, which is actually a vestigial tail, disappears, leaving it with four legs. The kangaroo is able to climb hills and mountains with its powerful hind legs and strong tail. The answer is a kangaroo. A kangaroo is born with three legs, but as it grows, the third leg, which is actually a vestigial tail, disappears, leaving it with four legs. The kangaroo is able to climb hills and mountains with its powerful hind legs and strong tail. The answer is a kangaroo. A kangaroo is born with three legs, but as it grows, the third leg, which is

# %%
import torch
from transformers import LlamaTokenizer, LlamaForCausalLM

tokenizer = LlamaTokenizer.from_pretrained('sarvamai/OpenHathi-7B-Hi-v0.1-Base')
model = LlamaForCausalLM.from_pretrained('sarvamai/OpenHathi-7B-Hi-v0.1-Base', torch_dtype=torch.bfloat16)
# Out:
# tokenizer_config.json:   0%|          | 0.00/936 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/968k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.85M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.81G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# 'animal that is born with 3 legs but goes up to the hill with 4 legs.\n\nचरण 2: वाक्य के संदर्भ को'

# %%
prompt = "एक प्लस 96 point panch क्या है"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
print(tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0])
# Out:
# एक प्लस 96 point panch क्या है ?
#
#  एक प्लस 96 point panch एक विशेष प्रकार का गोल बॉल है जिसे गेंद के रूप में भी जाना जाता है। यह एक खेल का सामान है जो

# %%
prompt = "Which animal has one leg"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
print(tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0])
# Out:
# Which animal has one leg
#
#   चिट्ठा जानवर एक पैर वाला है। यह एक विशेष प्रकार का कीट है जो अफ्रीका के उत्तरी भाग में पाया जाता है। यह एक अद्वितीय जानवर है और
